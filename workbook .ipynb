# %%
import pandas as pd
import numpy as np
import time
import datetime

# %%
county_annual_aqi_df = pd.read_csv('data/annual_aqi/annual_aqi_by_county_2020.csv')

# %%
county_annual_aqi_df.head()
# Out:
#      State     County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama    Baldwin  2020             11         11              0
# 1  Alabama       Clay  2020              5          5              0
# 2  Alabama     DeKalb  2020             59         59              0
# 3  Alabama     Etowah  2020              8          8              0
# 4  Alabama  Jefferson  2020             32         26              6
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
county_aqi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 19 columns):
# State                                  627 non-null object
# County                                 627 non-null object
# Year                                   627 non-null int64
# Days with AQI                          627 non-null int64
# Good Days                              627 non-null int64
# Moderate Days                          627 non-null int64
# Unhealthy for Sensitive Groups Days    627 non-null int64
# Unhealthy Days                         627 non-null int64
# Very Unhealthy Days                    627 non-null int64
# Hazardous Days                         627 non-null int64
# Max AQI                                627 non-null int64
# 90th Percentile AQI                    627 non-null int64
# Median AQI                             627 non-null int64
# Days CO                                627 non-null int64
# ...

# %%
county_aqi_daily_df = pd.read_csv('data/daily_aqi/daily_aqi_by_county_2020.csv')

# %%
county_aqi_daily_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41250 entries, 0 to 41249
# Data columns (total 10 columns):
# State Name                   41250 non-null object
# county Name                  41250 non-null object
# State Code                   41250 non-null int64
# County Code                  41250 non-null int64
# Date                         41250 non-null datetime64[ns]
# AQI                          41250 non-null int64
# Category                     41250 non-null object
# Defining Parameter           41250 non-null object
# Defining Site                41250 non-null object
# Number of Sites Reporting    41250 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 3.1+ MB

# %%
county_aqi_daily_df.head()
# Out:
#   State Name county Name  State Code  County Code       Date  AQI Category  \
# 0    Alabama     Baldwin           1            3 2020-01-01   48     Good
# 1    Alabama     Baldwin           1            3 2020-01-04   13     Good
# 2    Alabama     Baldwin           1            3 2020-01-07   14     Good
# 3    Alabama     Baldwin           1            3 2020-01-10   39     Good
# 4    Alabama     Baldwin           1            3 2020-01-13   29     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
len(county_aqi_daily_df['county Name'].unique())
# Out:
# 518

# %%
county_aqi_daily_df['Date'] = pd.to_datetime(county_aqi_daily_df['Date'], format='%Y-%m-%d', errors='ignore')

# %%
cc = county_aqi_daily_df.groupby(['County Code', 'county Name'])['Date'].max()
cc
# Out:
# County Code  county Name
# 1            Adams                  2020-05-01
#              Alachua                2020-03-31
#              Albany                 2020-03-31
#              Allegany               2020-03-31
#              Androscoggin           2020-04-30
#              Apache                 2020-03-31
#              Arkansas               2020-03-31
#              Barnstable             2020-02-29
#              District of Columbia   2020-03-31
#              Hawaii                 2020-02-29
#              Kent                   2020-02-29
# 3            Aiken                  2020-03-31
#              Albemarle              2020-03-31
#              Alexander              2020-03-31
#              Allegheny              2020-04-01
#              Allen                  2020-03-31
#              Anne Arundel           2020-03-31
#              Aroostook              2020-03-31
#              Ashley                 2020-03-31
# ...

# %%
x = 627*365
x
# Out:
# 228855

# %%
county_aqi_daily_df.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2020-01-01   48     Good
# 1    Alabama     Baldwin           1            3  2020-01-04   13     Good
# 2    Alabama     Baldwin           1            3  2020-01-07   14     Good
# 3    Alabama     Baldwin           1            3  2020-01-10   39     Good
# 4    Alabama     Baldwin           1            3  2020-01-13   29     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
county_aqi_daily_df['county Name'].unique()
# Out:
# array(['Baldwin', 'Clay', 'DeKalb', 'Etowah', 'Jefferson', 'Mobile',
#        'Montgomery', 'Morgan', 'Russell', 'Shelby', 'Sumter',
#        'Tuscaloosa', 'Denali ', 'Matanuska-Susitna ', 'Apache', 'Cochise',
#        'Coconino', 'Gila', 'La Paz', 'Maricopa', 'Mohave', 'Navajo',
#        'Pima', 'Pinal', 'Santa Cruz', 'Yavapai', 'Yuma', 'Arkansas',
#        'Ashley', 'Clark', 'Crittenden', 'Garland', 'Jackson', 'Newton',
#        'Polk', 'Pulaski', 'Union', 'Washington', 'Butte', 'Colusa',
#        'Fresno', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Madera',
#        'Mariposa', 'Merced', 'Nevada', 'Placer', 'Plumas', 'Riverside',
#        'Sacramento', 'San Benito', 'San Bernardino', 'San Diego',
#        'San Luis Obispo', 'Santa Barbara', 'Shasta', 'Stanislaus',
#        'Sutter', 'Tulare', 'Ventura', 'Yolo', 'Adams', 'Arapahoe',
#        'Archuleta', 'Boulder', 'Clear Creek', 'Denver', 'Douglas',
#        'El Paso', 'Fremont', 'Garfield', 'Gilpin', 'Gunnison', 'La Plata',
# ...

# %%
county_aqi_daily_df['Date']
# Out:
# 0        2020-01-01
# 1        2020-01-04
# 2        2020-01-07
# 3        2020-01-10
# 4        2020-01-13
# 5        2020-01-16
# 6        2020-01-19
# 7        2020-01-22
# 8        2020-01-25
# 9        2020-01-28
# 10       2020-01-31
# 11       2020-01-04
# 12       2020-01-07
# 13       2020-01-10
# 14       2020-01-16
# 15       2020-01-28
# 16       2020-01-01
# 17       2020-01-02
# 18       2020-01-03
# 19       2020-01-04
# 20       2020-01-05
# 21       2020-01-06
# 22       2020-01-07
# 23       2020-01-08
# 24       2020-01-09
# 25       2020-01-10
# 26       2020-01-12
# 27       2020-01-13
# 28       2020-01-14
# 29       2020-01-15
#             ...
# 41220    2020-03-02
# 41221    2020-03-03
# 41222    2020-03-04
# 41223    2020-03-05
# 41224    2020-03-06
# 41225    2020-03-07
# 41226    2020-03-08
# 41227    2020-03-09
# 41228    2020-03-10
# 41229    2020-03-11
# 41230    2020-03-12
# 41231    2020-03-13
# 41232    2020-03-14
# 41233    2020-03-15
# ...

# %%
Uinta_county = county_aqi_daily_df[county_aqi_daily_df['county Name'] == 'Uinta']

# %%
Uinta_county
# Out:
#       State Name county Name  State Code  County Code        Date  AQI  \
# 41159    Wyoming       Uinta          56           41  2020-01-01    4
# 41160    Wyoming       Uinta          56           41  2020-01-02    5
# 41161    Wyoming       Uinta          56           41  2020-01-03    5
# 41162    Wyoming       Uinta          56           41  2020-01-04    5
# 41163    Wyoming       Uinta          56           41  2020-01-05    4
# 41164    Wyoming       Uinta          56           41  2020-01-06    6
# 41165    Wyoming       Uinta          56           41  2020-01-07    3
# 41166    Wyoming       Uinta          56           41  2020-01-08    3
# 41167    Wyoming       Uinta          56           41  2020-01-09    4
# 41168    Wyoming       Uinta          56           41  2020-01-10    3
# 41169    Wyoming       Uinta          56           41  2020-01-11    3
# 41170    Wyoming       Uinta          56           41  2020-01-12    2
# ...

# %%
county_aqi_daily_df[county_aqi_daily_df['Date'] > '2020-03-01']
# Out:
#       State Name county Name  State Code  County Code        Date  AQI  \
# 430      Arizona      Apache           4            1  2020-03-02    9
# 431      Arizona      Apache           4            1  2020-03-03    6
# 432      Arizona      Apache           4            1  2020-03-04   13
# 433      Arizona      Apache           4            1  2020-03-05   13
# 434      Arizona      Apache           4            1  2020-03-06    8
# 435      Arizona      Apache           4            1  2020-03-07   12
# 436      Arizona      Apache           4            1  2020-03-08    6
# 437      Arizona      Apache           4            1  2020-03-09    6
# 438      Arizona      Apache           4            1  2020-03-10    6
# 439      Arizona      Apache           4            1  2020-03-11    3
# 440      Arizona      Apache           4            1  2020-03-12    3
# 441      Arizona      Apache           4            1  2020-03-13    3
# ...

# %%
county_aqi_daily_df[county_aqi_daily_df['Date'] > '2020-04-01']
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 2206   California      Colusa           6           11  2020-04-02    7
# 2207   California      Colusa           6           11  2020-04-03    9
# 2208   California      Colusa           6           11  2020-04-04    8
# 2301   California      Fresno           6           19  2020-04-02   39
# 2302   California      Fresno           6           19  2020-04-03   39
# 2303   California      Fresno           6           19  2020-04-04   42
# 2304   California      Fresno           6           19  2020-04-05    6
# 2305   California      Fresno           6           19  2020-04-06   39
# 2306   California      Fresno           6           19  2020-04-07   36
# 2307   California      Fresno           6           19  2020-04-08   39
# 2308   California      Fresno           6           19  2020-04-09   39
# 2309   California      Fresno           6           19  2020-04-10   39
# ...

# %%
#county_aqi_daily_df['Date'] = pd.to_datetime(county_aqi_daily_df['Date'], format='%Y%m%d', errors='coerce')

# %%
county_aqi_daily_df.head()
# Out:
#   State Name county Name  State Code  County Code Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  NaT   48     Good
# 1    Alabama     Baldwin           1            3  NaT   13     Good
# 2    Alabama     Baldwin           1            3  NaT   14     Good
# 3    Alabama     Baldwin           1            3  NaT   39     Good
# 4    Alabama     Baldwin           1            3  NaT   29     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
county_aqi_daily_df['State Name'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Country Of Mexico', 'Delaware',
#        'District Of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kentucky', 'Louisiana', 'Maine',
#        'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'Tennessee', 'Texas', 'Utah',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
hourly_CO_2020 = pd.read_csv('data/hourly_gas/hourly_42101_2020.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
hourly_CO_2020.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Date Local',
#        'Time Local', 'Date GMT', 'Time GMT', 'Sample Measurement',
#        'Units of Measure', 'MDL', 'Uncertainty', 'Qualifier', 'Method Type',
#        'Method Code', 'Method Name', 'State Name', 'County Name',
#        'Date of Last Change'],
#       dtype='object')

# %%
hourly_CO_2020['Date GMT'].max()
# Out:
# '2020-05-01'

# %%
len(hourly_CO_2020)
# Out:
# 181190

# %%
hourly_CO_2020['Date GMT'] = pd.to_datetime(hourly_CO_2020['Date GMT'], format='%Y%m%d', errors='coerce')

# %%
hourly_CO_2020.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Date Local',
#        'Time Local', 'Date GMT', 'Time GMT', 'Sample Measurement',
#        'Units of Measure', 'MDL', 'Uncertainty', 'Qualifier', 'Method Type',
#        'Method Code', 'Method Name', 'State Name', 'County Name',
#        'Date of Last Change'],
#       dtype='object')

# %%
count_aqi_daily_df['County Code'].unique()
# Out:
# array([  3,  27,  49,  55,  73,  97, 101, 103, 113, 117, 119, 125,  68,
#        170,   1,   5,   7,  12,  13,  15,  17,  19,  21,  23,  25,  35,
#         51,  67, 139, 143,  11,  29,  31,  39,  43,  47,  57,  61,  63,
#         65,  69,  71,  79,  83,  89,  99, 107, 111,  41,  45,  59,  77,
#        123,  26,  81,  91, 105, 115,  95, 121, 127, 135, 151, 153, 185,
#        215, 231, 245, 295, 303,  53,  85, 157, 161, 163, 167, 179, 197,
#        201,  37, 129, 145, 147, 141, 169, 173, 183,  33, 137, 155, 177,
#        193,  93, 175, 199, 221, 227, 229,  87,   9, 510, 165,  75, 109,
#        131, 159, 133, 203, 233, 251, 255, 257, 273, 323, 309, 331, 349,
#        355, 361, 367, 373, 375, 381, 395, 397, 401, 423, 439, 449, 453,
#        469, 479, 493, 520,  36, 650, 670, 680, 710, 760, 775, 810, 840])

# %%
county_aqi_daily_df[['State Code', 'County Code', 'State Name', 'county Name']]
# Out:
#        State Code  County Code State Name county Name
# 0               1            3    Alabama     Baldwin
# 1               1            3    Alabama     Baldwin
# 2               1            3    Alabama     Baldwin
# 3               1            3    Alabama     Baldwin
# 4               1            3    Alabama     Baldwin
# 5               1            3    Alabama     Baldwin
# 6               1            3    Alabama     Baldwin
# 7               1            3    Alabama     Baldwin
# 8               1            3    Alabama     Baldwin
# 9               1            3    Alabama     Baldwin
# 10              1            3    Alabama     Baldwin
# 11              1           27    Alabama        Clay
# 12              1           27    Alabama        Clay
# 13              1           27    Alabama        Clay
# 14              1           27    Alabama        Clay
# 15              1           27    Alabama        Clay
# ...

# %%
hourly_CO_2020.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42101    2  33.553056
# 1           1           73        23           42101    2  33.553056
# 2           1           73        23           42101    2  33.553056
# 3           1           73        23           42101    2  33.553056
# 4           1           73        23           42101    2  33.553056
#
#    Longitude  Datum   Parameter Name  Date Local         ...           \
# 0    -86.815  WGS84  Carbon monoxide  2020-01-01         ...
# 1    -86.815  WGS84  Carbon monoxide  2020-01-01         ...
# 2    -86.815  WGS84  Carbon monoxide  2020-01-01         ...
# 3    -86.815  WGS84  Carbon monoxide  2020-01-01         ...
# 4    -86.815  WGS84  Carbon monoxide  2020-01-01         ...
#
#     Units of Measure  MDL Uncertainty  Qualifier Method Type  Method Code  \
# 0  Parts per million  0.5         NaN        NaN         FRM           93
# ...

# %%
hourly_CO_2020.describe()
# Out:
#           State Code    County Code       Site Num  Parameter Code  \
# count  181190.000000  181190.000000  181190.000000        181190.0
# mean       31.788382      58.863127     848.425272         42101.0
# std        14.271075      64.281272    1550.053365             0.0
# min         1.000000       1.000000       1.000000         42101.0
# 25%        22.000000      23.000000      17.000000         42101.0
# 50%        36.000000      35.000000      56.000000         42101.0
# 75%        42.000000      73.000000    1025.000000         42101.0
# max        56.000000     479.000000    9997.000000         42101.0
#
#                  POC       Latitude      Longitude  Sample Measurement  \
# count  181190.000000  181190.000000  181190.000000       181190.000000
# mean        1.173348      38.975987     -91.485376            0.255826
# std         0.576767       3.907335      14.975403            0.236175
# min         1.000000      27.517456    -124.624910           -0.300000
# ...

# %%
county_list = county_aqi_daily_df['county Name'].unique()

# %%
hourly_CO_2020.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Date Local',
#        'Time Local', 'Date GMT', 'Time GMT', 'Sample Measurement',
#        'Units of Measure', 'MDL', 'Uncertainty', 'Qualifier', 'Method Type',
#        'Method Code', 'Method Name', 'State Name', 'County Name',
#        'Date of Last Change'],
#       dtype='object')

# %%
hourly_CO_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181190 entries, 0 to 181189
# Data columns (total 24 columns):
# State Code             181190 non-null int64
# County Code            181190 non-null int64
# Site Num               181190 non-null int64
# Parameter Code         181190 non-null int64
# POC                    181190 non-null int64
# Latitude               181190 non-null float64
# Longitude              181190 non-null float64
# Datum                  181190 non-null object
# Parameter Name         181190 non-null object
# Date Local             181190 non-null object
# Time Local             181190 non-null object
# Date GMT               0 non-null datetime64[ns]
# Time GMT               181190 non-null object
# Sample Measurement     181190 non-null float64
# Units of Measure       181190 non-null object
# MDL                    181190 non-null float64
# Uncertainty            0 non-null float64
# Qualifier              2524 non-null object
# ...

# %%
ccgroup = hourly_CO_2020.groupby(['State Name', 'County Name'])['Date GMT'].max().reset_index()
ccgroup_sufficient = ccgroup[ccgroup['Date GMT'] >= '2020-04-24']

# %%
ccgroup_sufficient
# Out:
# 11

# %%
ozone_df = pd.read_csv('data/hourly_gas/hourly_44201_2020.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ozone_df.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           49      9991           44201    1  34.289001
# 1           1           49      9991           44201    1  34.289001
# 2           1           49      9991           44201    1  34.289001
# 3           1           49      9991           44201    1  34.289001
# 4           1           49      9991           44201    1  34.289001
#
#    Longitude  Datum Parameter Name  Date Local         ...           \
# 0 -85.970065  NAD83          Ozone  2020-01-01         ...
# 1 -85.970065  NAD83          Ozone  2020-01-01         ...
# 2 -85.970065  NAD83          Ozone  2020-01-01         ...
# 3 -85.970065  NAD83          Ozone  2020-01-01         ...
# 4 -85.970065  NAD83          Ozone  2020-01-01         ...
#
#     Units of Measure    MDL Uncertainty  Qualifier Method Type  Method Code  \
# 0  Parts per million  0.005         NaN        NaN         FEM           47
# ...

# %%
ozone_df.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Date Local',
#        'Time Local', 'Date GMT', 'Time GMT', 'Sample Measurement',
#        'Units of Measure', 'MDL', 'Uncertainty', 'Qualifier', 'Method Type',
#        'Method Code', 'Method Name', 'State Name', 'County Name',
#        'Date of Last Change'],
#       dtype='object')

# %%
ozone_df['Date GMT'] = pd.to_datetime(ozone_df['Date GMT'], format='%Y-%m-%d', errors='ignore')

# %%
ogroup = ozone_df.groupby(['State Name', 'County Name'])['Date GMT'].max().reset_index()
ogroup_sufficient = ogroup[ogroup['Date GMT'] >= '2020-04-01']
len(ogroup_sufficient)
# Out:
# 228

# %%
ogroup_sufficient
# Out:
#             State Name   County Name   Date GMT
# 4              Arizona      Coconino 2020-04-01
# 5              Arizona          Gila 2020-04-01
# 6              Arizona        La Paz 2020-04-01
# 7              Arizona      Maricopa 2020-04-01
# 9              Arizona         Pinal 2020-04-01
# 10             Arizona       Yavapai 2020-04-01
# 11             Arizona          Yuma 2020-04-01
# 13            Arkansas    Crittenden 2020-04-01
# 14            Arkansas        Newton 2020-04-01
# 15            Arkansas          Polk 2020-04-01
# 16            Arkansas       Pulaski 2020-04-01
# 17            Arkansas    Washington 2020-04-01
# 18          California        Fresno 2020-05-01
# 20          California         Kings 2020-04-01
# 22          California        Nevada 2020-05-01
# 31          California       Ventura 2020-04-01
# 32            Colorado         Adams 2020-04-01
# 33            Colorado      Arapahoe 2020-04-01
# 34            Colorado       Boulder 2020-04-01
# ...

# %%
ozone_df.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Date Local',
#        'Time Local', 'Date GMT', 'Time GMT', 'Sample Measurement',
#        'Units of Measure', 'MDL', 'Uncertainty', 'Qualifier', 'Method Type',
#        'Method Code', 'Method Name', 'State Name', 'County Name',
#        'Date of Last Change'],
#       dtype='object')

# %%
king = ozone_df[(ozone_df['State Name'] == 'Washington') & (ozone_df['County Name'] == 'King')]

# %%
king[['Date Local', 'Date GMT', 'Time Local', 'Date of Last Change']]
# Out:
#         Date Local   Date GMT Time Local Date of Last Change
# 773414  2020-01-01 2020-01-01      00:00          2020-04-30
# 773415  2020-01-01 2020-01-01      01:00          2020-04-30
# 773416  2020-01-01 2020-01-01      02:00          2020-04-30
# 773417  2020-01-01 2020-01-01      03:00          2020-04-30
# 773418  2020-01-01 2020-01-01      04:00          2020-04-30
# 773419  2020-01-01 2020-01-01      05:00          2020-04-30
# 773420  2020-01-01 2020-01-01      06:00          2020-04-30
# 773421  2020-01-01 2020-01-01      07:00          2020-04-30
# 773422  2020-01-01 2020-01-01      08:00          2020-04-30
# 773423  2020-01-01 2020-01-01      09:00          2020-04-30
# 773424  2020-01-01 2020-01-01      10:00          2020-04-30
# 773425  2020-01-01 2020-01-01      11:00          2020-04-30
# 773426  2020-01-01 2020-01-01      12:00          2020-04-30
# 773427  2020-01-01 2020-01-01      13:00          2020-04-30
# ...

# %%
county_annualaqi_df2019 = pd.read_csv('data/daily_aqi/daily_aqi_by_county_2019.csv')

# %%
county_annualaqi_df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340169 entries, 0 to 340168
# Data columns (total 10 columns):
# State Name                   340169 non-null object
# county Name                  340169 non-null object
# State Code                   340169 non-null int64
# County Code                  340169 non-null int64
# Date                         340169 non-null object
# AQI                          340169 non-null int64
# Category                     340169 non-null object
# Defining Parameter           340169 non-null object
# Defining Site                340169 non-null object
# Number of Sites Reporting    340169 non-null int64
# dtypes: int64(4), object(6)
# memory usage: 26.0+ MB

# %%
county_annualaqi_df2019[county_annualaqi_df2019['county Name'] == 'King']
# Out:
#         State Name county Name  State Code  County Code        Date  AQI  \
# 314397  Washington        King          53           33  2019-01-01   87
# 314398  Washington        King          53           33  2019-01-02   54
# 314399  Washington        King          53           33  2019-01-03   52
# 314400  Washington        King          53           33  2019-01-04   43
# 314401  Washington        King          53           33  2019-01-05   48
# 314402  Washington        King          53           33  2019-01-06   32
# 314403  Washington        King          53           33  2019-01-07   38
# 314404  Washington        King          53           33  2019-01-08   49
# 314405  Washington        King          53           33  2019-01-09   41
# 314406  Washington        King          53           33  2019-01-10   31
# 314407  Washington        King          53           33  2019-01-11   55
# 314408  Washington        King          53           33  2019-01-12   68
# ...

# %%
import requests
def get_hist_info(zipcode:str, date:str, distance:int=50) -> dict:
    req_url = '''http://www.airnowapi.org/aq/observation/zipCode/historical/?format=application/json&zipCode=%s&date=%sT00-0000&distance=%s&API_KEY=9AF5ED39-FAA2-4BBD-AD3D-E90F7178E17F'''
    return requests.get(req_url % (str(zipcode), str(date), str(distance))).json()
# Out:
# [{'DateObserved': '2020-03-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Hartford',
#   'StateCode': 'CT',
#   'Latitude': 41.785,
#   'Longitude': -72.63,
#   'ParameterName': 'OZONE',
#   'AQI': 38,
#   'Category': {'Number': 1, 'Name': 'Good'}},
#  {'DateObserved': '2020-03-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Hartford',
#   'StateCode': 'CT',
#   'Latitude': 41.785,
#   'Longitude': -72.63,
#   'ParameterName': 'PM2.5',
#   'AQI': 20,
#   'Category': {'Number': 1, 'Name': 'Good'}},
#  {'DateObserved': '2020-03-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Hartford',
#   'StateCode': 'CT',
#   'Latitude': 41.785,
#   'Longitude': -72.63,
#   'ParameterName': 'PM10',
#   'AQI': 8,
#   'Category': {'Number': 1, 'Name': 'Good'}}]

# %%
already_done_1 = ['35801', '99501', '85001']
zip_codes1 = ['72201', '94203', '90001', 
             '90209', '94016', '80201', '06101', '19901', '20001', 
             '32501', '33124', '32801', '30301', '96801', '83254',
             '10001', '60007', '83702', '62701', '46201', '52801',
             '50301', '67201', '40514', '70112', '04101', '21201',
             '02101', '48202', '48104', '49504', '55801', '55401']

zip_codes2 = ['39530', '63101', '59801', '59715', '68502', '89501',
             '89104', '03217', '07039', '87500', '87102', '27514',
             '27601', '58282', '44101', '74101', '97201', '15201',
             '19106', '02840', '29401', '57401', '37201', '78701',
             '77002', '75202', '78205', '84150', '05401', '23219',
             '23510', '25813', '53201', '32204', '53715', '83001']

dates = pd.date_range(start='2020-03-01', end='2020-06-30')
dates_str = [str(x).split()[0] for x in dates]
dates_str
# Out:
# ['2020-03-01',
#  '2020-03-02',
#  '2020-03-03',
#  '2020-03-04',
#  '2020-03-05',
#  '2020-03-06',
#  '2020-03-07',
#  '2020-03-08',
#  '2020-03-09',
#  '2020-03-10',
#  '2020-03-11',
#  '2020-03-12',
#  '2020-03-13',
#  '2020-03-14',
#  '2020-03-15',
#  '2020-03-16',
#  '2020-03-17',
#  '2020-03-18',
#  '2020-03-19',
#  '2020-03-20',
#  '2020-03-21',
#  '2020-03-22',
#  '2020-03-23',
#  '2020-03-24',
#  '2020-03-25',
#  '2020-03-26',
#  '2020-03-27',
#  '2020-03-28',
#  '2020-03-29',
#  '2020-03-30',
#  '2020-03-31',
#  '2020-04-01',
#  '2020-04-02',
#  '2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
# ...

# %%
countme = 0
test_df = pd.DataFrame()
for zipc in zip_codes1:
    for date in dates_str:
        print(zipc, date, countme)
        x = get_hist_info(zipc, date)
        df = pd.DataFrame(x)
        test_df = pd.concat([test_df, df])
        countme += 1
        if countme >= 480:
            print('sleeping')
            print(datetime.datetime.now())
            time.sleep(3600)
            countme = 0
            
    test_df.to_csv('data/2020aqi2.tsv', sep='\t')
# Out:
# 72201 2020-03-01 0
# 72201 2020-03-02 1
# 72201 2020-03-03 2
# 72201 2020-03-04 3
# 72201 2020-03-05 4
# 72201 2020-03-06 5
# 72201 2020-03-07 6
# 72201 2020-03-08 7
# 72201 2020-03-09 8
# 72201 2020-03-10 9
# 72201 2020-03-11 10
# 72201 2020-03-12 11
# 72201 2020-03-13 12
# 72201 2020-03-14 13
# 72201 2020-03-15 14
# 72201 2020-03-16 15
# 72201 2020-03-17 16
# 72201 2020-03-18 17
# 72201 2020-03-19 18
# 72201 2020-03-20 19
# 72201 2020-03-21 20
# 72201 2020-03-22 21
# 72201 2020-03-23 22
# 72201 2020-03-24 23
# 72201 2020-03-25 24
# 72201 2020-03-26 25
# 72201 2020-03-27 26
# 72201 2020-03-28 27
# 72201 2020-03-29 28
# 72201 2020-03-30 29
# 72201 2020-03-31 30
# 72201 2020-04-01 31
# 72201 2020-04-02 32
# 72201 2020-04-03 33
# 72201 2020-04-04 34
# 72201 2020-04-05 35
# 72201 2020-04-06 36
# 72201 2020-04-07 37
# 72201 2020-04-08 38
# 72201 2020-04-09 39
# 72201 2020-04-10 40
# 72201 2020-04-11 41
# 72201 2020-04-12 42
# 72201 2020-04-13 43
# 72201 2020-04-14 44
# ...

# %%
print(datetime.datetime.now())
# Out:
# 2020-07-20 19:02:59.524475

# %%
test_df.columns
# Out:
# Index(['AQI', 'Category', 'DateObserved', 'HourObserved', 'Latitude',
#        'LocalTimeZone', 'Longitude', 'ParameterName', 'ReportingArea',
#        'StateCode'],
#       dtype='object')

# %%
dates
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10',
#                ...
#                '2020-06-21', '2020-06-22', '2020-06-23', '2020-06-24',
#                '2020-06-25', '2020-06-26', '2020-06-27', '2020-06-28',
#                '2020-06-29', '2020-06-30'],
#               dtype='datetime64[ns]', length=122, freq='D')
